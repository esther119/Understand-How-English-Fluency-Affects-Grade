# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('readibility_process_data.zip')

# %%
df = df[df['Poll Responses Response'].notnull()]

# %%
AH_data = df[df['College'] == 'AH']
CS_data = df[df['College'] == 'CS']
NS_data = df[df['College'] == 'NS']
SS_data = df[df['College'] == 'SS']

# %%
len(AH_data), len(CS_data), len(NS_data), len(SS_data)
# Out:
# (43707, 43185, 38579, 38554)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
AH_data.name = 'AH_data'
CS_data.name = 'CS_data'
NS_data.name = 'NS_data'
SS_data.name = 'SS_data'

# %% [markdown]
# ## AH data

# %%
import scipy.stats as sts
def correlation_comparison(dataset, y_column): 
    x= np.array(dataset['Assessment reports Score']) 
    y = np.array(dataset[y_column])


    code_coef = np.corrcoef(x, y)
    r_pear, p_pear = sts.pearsonr(x, y)
    r_spear, p_spear = sts.spearmanr(x, y)
    r_kend, p_kend = sts.kendalltau(x, y)

    r_z = np.arctanh(r_pear)

    print(f'Mean of readability:{np.mean(y)} and std of readability:{np.std(y)}')
    plt.title(f"Readability score distribution in the {dataset.name} group")
    sns.distplot(y)
    # plt.text(0.5, 0.5, 'matplotlib', ha='right', va='top')

    plt.annotate(f'Mean:{round(np.mean(y),2)}, std:{round(np.std(y),2)}', xy=(0.05, 0.95), xycoords='axes fraction')
    plt.show()

    print(f'The correlation between Assessment reports Score and {y_column}')
    print(f'Person r and p value:{r_pear, p_pear}')
    print(f'Spearman r and p value:{r_spear, p_spear}')
    print(f'Kendalltau r and p value:{r_kend, p_kend}')
    print(f'Fisher z-transformation value:{r_z}')
    
    sns.set_palette('rainbow')
    sns.boxplot(x=x, y=y)
    plt.xlabel('Grade')
    plt.ylabel('Readability score')
    plt.title(f"Readability score by grade in the {dataset.name} group")
    plt.show()

    sns.violinplot(data=df, x=x, y = y,  scale='width')
    plt.xlabel('Grade')
    plt.ylabel('Readability score')    
    plt.title(f"Readability score by grade in the {dataset.name} group")
    plt.show()

# %%
correlation_comparison(AH_data, 'dale_chall_readability_score')
# Out:
# Mean of readability:14.201315807536549 and std of readability:1.657415975855983
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and dale_chall_readability_score
# Person r and p value:(0.06839184307899665, 1.7763347029736082e-46)
# Spearman r and p value:(0.07694972829659089, 2.145495505936817e-58)
# Kendalltau r and p value:(0.060808854084651004, 6.4169233443802814e-59)
# Fisher z-transformation value:0.06849877635437049

# %%
correlation_comparison(AH_data, 'automated_readability_index')
# Out:
# Mean of readability:25.98185187727366 and std of readability:5.677938985285298
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and automated_readability_index
# Person r and p value:(0.24436483289869457, 0.0)
# Spearman r and p value:(0.21193180816710036, 0.0)
# Kendalltau r and p value:(0.1680663625567306, 0.0)
# Fisher z-transformation value:0.24941091391878417

# %% [markdown]
# # CS data

# %%
correlation_comparison(CS_data, 'dale_chall_readability_score')
# Out:
# Mean of readability:13.434851916174596 and std of readability:2.050246669605661
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and dale_chall_readability_score
# Person r and p value:(0.01863069240730276, 0.00010800430088244665)
# Spearman r and p value:(0.01812268125894481, 0.00016570139283699587)
# Kendalltau r and p value:(0.01417839981752374, 0.00014648011510824614)
# Fisher z-transformation value:0.018632848444216827

# %%
correlation_comparison(CS_data, 'automated_readability_index')
# Out:
# Mean of readability:22.278832928100034 and std of readability:7.6531372452755075
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and automated_readability_index
# Person r and p value:(0.22468864216008266, 0.0)
# Spearman r and p value:(0.19406098880996311, 0.0)
# Kendalltau r and p value:(0.15253579746630017, 0.0)
# Fisher z-transformation value:0.2285886101414494

# %% [markdown]
# ## NS data

# %%
correlation_comparison(NS_data, 'dale_chall_readability_score')
# Out:
# Mean of readability:14.106046035407864 and std of readability:1.671984119739141
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and dale_chall_readability_score
# Person r and p value:(0.07507912870879259, 2.3890276802446823e-49)
# Spearman r and p value:(0.07687050851185655, 1.1875328568013427e-51)
# Kendalltau r and p value:(0.06008020669682466, 6.219117781424265e-52)
# Fisher z-transformation value:0.07522067832539339

# %%
correlation_comparison(NS_data, 'automated_readability_index')
# Out:
# Mean of readability:24.381746546048365 and std of readability:6.647665815352055
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and automated_readability_index
# Person r and p value:(0.264726134899621, 0.0)
# Spearman r and p value:(0.25254425406792186, 0.0)
# Kendalltau r and p value:(0.19909287561022196, 0.0)
# Fisher z-transformation value:0.2711839240907591

# %% [markdown]
# ## SS data

# %%
correlation_comparison(SS_data, 'dale_chall_readability_score')
# Out:
# Mean of readability:14.154165326554963 and std of readability:1.6290552425567295
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and dale_chall_readability_score
# Person r and p value:(0.08590667095526029, 4.605488917855355e-64)
# Spearman r and p value:(0.07807405343070886, 3.386172547652179e-53)
# Kendalltau r and p value:(0.061350463510232454, 2.48649148549193e-53)
# Fisher z-transformation value:0.08611894083030479

# %%
correlation_comparison(SS_data, 'automated_readability_index')
# Out:
# Mean of readability:26.378764849302275 and std of readability:5.8312395679784625
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and automated_readability_index
# Person r and p value:(0.23318613507384353, 0.0)
# Spearman r and p value:(0.20760407154083327, 0.0)
# Kendalltau r and p value:(0.1640178985318079, 0.0)
# Fisher z-transformation value:0.23755618017580651

# %%
import pingouin as pg

# %%
from statsmodels.stats.weightstats import ttest_ind
import numpy as np

# %%
AH_score = AH_data['dale_chall_readability_score']
CS_score = CS_data['dale_chall_readability_score']
NS_score = NS_data['dale_chall_readability_score']
SS_score = SS_data['dale_chall_readability_score']

# %% [markdown]
# ## AH fluency vs CS fluency

# %%
result = pg.ttest(AH_score,
                  CS_score,
                  correction=True)
 
# Print the result
result
# Out:
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/pingouin/bayesian.py:152: RuntimeWarning: divide by zero encountered in double_scalars
#   bf10 = 1 / ((1 + t**2 / df) ** (-(df + 1) / 2) / integr)
#                 T           dof alternative  p-val         CI95%   cohen-d  \
# T-test  60.557972  82833.418584   two-sided    0.0  [0.74, 0.79]  0.411402
#
#        BF10  power
# T-test  inf    1.0

# %% [markdown]
# ## AH vs NS

# %%
result = pg.ttest(AH_score,
                  NS_score,
                  correction=True)
 
# Print the result
result
# Out:
#                T          dof alternative         p-val         CI95%  \
# T-test  8.189913  80840.78418   two-sided  2.651855e-16  [0.07, 0.12]
#
#          cohen-d       BF10  power
# T-test  0.057244  2.839e+12    1.0

# %% [markdown]
# ## AH vs SS

# %%
result = pg.ttest(AH_score,
                  SS_score,
                  correction=True)
 
# Print the result
result
# Out:
#               T           dof alternative    p-val         CI95%   cohen-d  \
# T-test  4.10878  81305.531054   two-sided  0.00004  [0.02, 0.07]  0.028677
#
#           BF10     power
# T-test  36.443  0.983997

# %% [markdown]
# ## CS vs NS

# %%
result = pg.ttest(CS_score,
                  NS_score,
                  correction=True)
 
# Print the result
result
# Out:
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/pingouin/bayesian.py:152: RuntimeWarning: divide by zero encountered in double_scalars
#   bf10 = 1 / ((1 + t**2 / df) ** (-(df + 1) / 2) / integr)
#                T           dof alternative  p-val          CI95%   cohen-d  \
# T-test -51.50795  81100.658705   two-sided    0.0  [-0.7, -0.65]  0.356773
#
#        BF10  power
# T-test  inf    1.0

# %% [markdown]
# ## CS vs SS

# %%
result = pg.ttest(CS_score,
                  SS_score,
                  correction=True)
 
# Print the result
result
# Out:
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/pingouin/bayesian.py:152: RuntimeWarning: divide by zero encountered in double_scalars
#   bf10 = 1 / ((1 + t**2 / df) ** (-(df + 1) / 2) / integr)
#                 T           dof alternative  p-val           CI95%  cohen-d  \
# T-test -55.800108  80669.098969   two-sided    0.0  [-0.74, -0.69]    0.386
#
#        BF10  power
# T-test  inf    1.0

# %% [markdown]
# ## NS vs SS

# %%
result = pg.ttest(NS_score,
                  SS_score,
                  correction=True)
 
# Print the result
result
# Out:
#                T           dof alternative     p-val           CI95%  \
# T-test -4.048071  77081.438836   two-sided  0.000052  [-0.07, -0.02]
#
#          cohen-d    BF10     power
# T-test  0.029151  29.321  0.981602

# %% [markdown]
# # Distribution plot

# %%
sns.distplot(CS_score, hist=False, label= 'CS')
sns.distplot(NS_score, hist=False, label= 'NS')
sns.distplot(SS_score, hist=False, label= 'SS')
sns.distplot(AH_score, hist=False, label= 'AH')
plt.title('Readability distribution for different colleges')
plt.legend()
# Out:
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
def comparison_stats(dataset1, dataset2):    
    effect_size = pg.compute_effsize(dataset1, dataset2, paired=False, eftype='cohen')
    n_dataset1 = len(dataset1)
    s_dataset1 = np.var(dataset1)
    n_dataset2 = len(dataset2)
    s_dataset2 = np.var(dataset2)

    std = np.sqrt(((n_dataset1 - 1) * n_dataset2 + (n_dataset2 - 1) * s_dataset2) / (n_dataset1 + n_dataset2 - 2))
    t_test = pg.ttest(dataset1, dataset2,correction=True)
    return [effect_size, std, t_test['p-val'][0], t_test['T'][0]]

table_data = []   
AH_CS = comparison_stats(AH_score,CS_score)
AH_SS = comparison_stats(AH_score,SS_score)
AH_NS = comparison_stats(AH_score,NS_score)
NS_CS = comparison_stats(NS_score,CS_score)
SS_CS = comparison_stats(SS_score,CS_score)
NS_SS = comparison_stats(NS_score,SS_score)

table_data.append(['AH vs CS', AH_CS[0], AH_CS[1], AH_CS[2], AH_CS[3]])
table_data.append(['AH vs SS', AH_SS[0], AH_SS[1], AH_SS[2], AH_SS[3]])
table_data.append(['AH vs NS', AH_NS[0], AH_NS[1], AH_NS[2], AH_NS[3]])
table_data.append(['NS vs CS', NS_CS[0], NS_CS[1], NS_CS[2], NS_CS[3]])
table_data.append(['SS vs CS', SS_CS[0], SS_CS[1], SS_CS[2], SS_CS[3]])
table_data.append(['NS vs SS', NS_SS[0], NS_SS[1], NS_SS[2], NS_SS[3]])


plot_df = pd.DataFrame(table_data, columns=['Comparison', 'Effect_size', 'Error', 'P value', 'T'])
plot_df
# Out:
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/pingouin/bayesian.py:152: RuntimeWarning: divide by zero encountered in double_scalars
#   bf10 = 1 / ((1 + t**2 / df) ** (-(df + 1) / 2) / integr)
#   Comparison  Effect_size       Error       P value          T
# 0   AH vs CS     0.411402  147.391683  0.000000e+00  60.557972
# 1   AH vs SS     0.028677  143.128699  3.981436e-05   4.108780
# 2   AH vs NS     0.057244  143.153577  2.651855e-16   8.189913
# 3   NS vs CS     0.356773  142.752664  0.000000e+00  51.507950
# 4   SS vs CS     0.386000  142.728229  0.000000e+00  55.800108
# 5   NS vs SS    -0.029151  138.868912  5.169193e-05  -4.048071

# %%
len(AH_data), len(CS_data), len(NS_data), len(SS_data)
# Out:
# (43707, 43185, 38579, 38554)
