# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('readibility_process_data.zip')

# %%
df = df[df['Poll Responses Response'].notnull()]

# %%
AH_data = df[df['College'] == 'AH']
CS_data = df[df['College'] == 'CS']
NS_data = df[df['College'] == 'NS']
SS_data = df[df['College'] == 'SS']

# %%
len(AH_data), len(CS_data), len(NS_data), len(SS_data)
# Out:
# (43045, 42103, 38421, 38518)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
AH_data.name = 'AH_data'
CS_data.name = 'CS_data'
NS_data.name = 'NS_data'
SS_data.name = 'SS_data'

# %% [markdown]
# ## AH data

# %%
import scipy.stats as sts
def correlation_comparison(dataset, y_column): 
    x= np.array(dataset['Assessment reports Score']) 
    y = np.array(dataset[y_column])


    code_coef = np.corrcoef(x, y)
    r_pear, p_pear = sts.pearsonr(x, y)
    r_spear, p_spear = sts.spearmanr(x, y)
    r_kend, p_kend = sts.kendalltau(x, y)

    r_z = np.arctanh(r_pear)

    print(f'Mean of readability:{np.mean(y)} and std of readability:{np.std(y)}')
    plt.title(f"Readability score distribution in the {dataset.name} group")
    sns.distplot(y)
    # plt.text(0.5, 0.5, 'matplotlib', ha='right', va='top')

    plt.annotate(f'Mean:{round(np.mean(y),2)}, std:{round(np.std(y),2)}', xy=(0.05, 0.95), xycoords='axes fraction')
    plt.show()

    print(f'The correlation between Assessment reports Score and {y_column}')
    print(f'Person r and p value:{r_pear, p_pear}')
    print(f'Spearman r and p value:{r_spear, p_spear}')
    print(f'Kendalltau r and p value:{r_kend, p_kend}')
    print(f'Fisher z-transformation value:{r_z}')
    
    sns.set_palette('rainbow')
    sns.boxplot(x=x, y=y)
    plt.xlabel('Grade')
    plt.ylabel('Readability score')
    plt.title(f"Readability score by grade in the {dataset.name} group")
    plt.show()

    sns.violinplot(data=df, x=x, y = y,  scale='width')
    plt.xlabel('Grade')
    plt.ylabel('Readability score')    
    plt.title(f"Readability score by grade in the {dataset.name} group")
    plt.show()

# %%
correlation_comparison(AH_data, 'dale_chall_readability_score')
# Out:
# Mean of readability:14.135811824834477 and std of readability:1.571876754975607
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and dale_chall_readability_score
# Person r and p value:(0.08542432930626577, 1.5717059102570306e-70)
# Spearman r and p value:(0.08305158563363076, 9.366264154415896e-67)
# Kendalltau r and p value:(0.06552023631902229, 5.2740926190380885e-67)
# Fisher z-transformation value:0.08563303330135144

# %%
correlation_comparison(AH_data, 'automated_readability_index')
# Out:
# Mean of readability:26.080750377511908 and std of readability:5.638916660784994
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and automated_readability_index
# Person r and p value:(0.24866956450849648, 0.0)
# Spearman r and p value:(0.21455522942593663, 0.0)
# Kendalltau r and p value:(0.17028530829425592, 0.0)
# Fisher z-transformation value:0.2539941830451622

# %% [markdown]
# # CS data

# %%
correlation_comparison(CS_data, 'dale_chall_readability_score')
# Out:
# Mean of readability:13.310919174405624 and std of readability:1.905287883947479
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and dale_chall_readability_score
# Person r and p value:(0.01446591374975754, 0.002994224171811127)
# Spearman r and p value:(0.0128575798141639, 0.008332786631433251)
# Kendalltau r and p value:(0.010003253171463706, 0.008191014893811958)
# Fisher z-transformation value:0.014466922935004614

# %%
correlation_comparison(CS_data, 'automated_readability_index')
# Out:
# Mean of readability:22.401429826853196 and std of readability:7.646888161631662
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and automated_readability_index
# Person r and p value:(0.23225758266814897, 0.0)
# Spearman r and p value:(0.20187750398080415, 0.0)
# Kendalltau r and p value:(0.15880634378411781, 0.0)
# Fisher z-transformation value:0.23657445814481928

# %% [markdown]
# ## NS data

# %%
correlation_comparison(NS_data, 'dale_chall_readability_score')
# Out:
# Mean of readability:14.090164233101689 and std of readability:1.6528971488770439
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and dale_chall_readability_score
# Person r and p value:(0.07394219173729985, 1.002239921383266e-47)
# Spearman r and p value:(0.07515727712227877, 2.9791815155400813e-49)
# Kendalltau r and p value:(0.0587186995965315, 1.7458879109398576e-49)
# Fisher z-transformation value:0.07407739389750906

# %%
correlation_comparison(NS_data, 'automated_readability_index')
# Out:
# Mean of readability:24.401834934020457 and std of readability:6.642150362549944
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and automated_readability_index
# Person r and p value:(0.2672732163534017, 0.0)
# Spearman r and p value:(0.255346943726121, 0.0)
# Kendalltau r and p value:(0.20132060097011073, 0.0)
# Fisher z-transformation value:0.27392495111274173

# %% [markdown]
# ## SS data

# %%
correlation_comparison(SS_data, 'dale_chall_readability_score')
# Out:
# Mean of readability:14.151549665091645 and std of readability:1.6262841942296338
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and dale_chall_readability_score
# Person r and p value:(0.08647615965681861, 7.786241827682432e-65)
# Spearman r and p value:(0.0781365410003805, 3.1276769108720896e-53)
# Kendalltau r and p value:(0.06139716865980812, 2.3279520417506305e-53)
# Fisher z-transformation value:0.08669269192178393

# %%
correlation_comparison(SS_data, 'automated_readability_index')
# Out:
# Mean of readability:26.382639285528843 and std of readability:5.82978377463359
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# The correlation between Assessment reports Score and automated_readability_index
# Person r and p value:(0.2336113621149277, 0.0)
# Spearman r and p value:(0.20786020082155646, 0.0)
# Kendalltau r and p value:(0.16422271806676644, 0.0)
# Fisher z-transformation value:0.23800590603028887

# %%
import pingouin as pg

# %%
from statsmodels.stats.weightstats import ttest_ind
import numpy as np
# Out:
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.1, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
print(np.mean(writing_read_score), np.mean(code_read_score), np.mean(code_math_read_score), np.mean(the_rest_read_score))
print(np.var(writing_read_score), np.var(code_read_score), np.var(code_math_read_score), np.var(the_rest_read_score))
# Out:
# 13.810671232876716 11.262606232294612 11.467260677466875 13.970273883588863
# 3.146189138487516 3.02509519055606 5.1664879305744975 2.9146218667534445

# %%
AH_score = df[df['College'] == 'AH']
CS_score = df[df['College'] == 'CS']
NS_score = df[df['College'] == 'NS']
SS_score = df[df['College'] == 'SS']

# %% [markdown]
# ## AH fluency vs CS fluency

# %%
result = pg.ttest(writing_read_score,
                  code_read_score,
                  correction=True)
 
# Print the result
result
# Out:
#                 T         dof alternative         p-val         CI95%  \
# T-test  24.575239  542.567297   two-sided  3.360402e-90  [2.34, 2.75]
#
#          cohen-d       BF10  power
# T-test  1.441159  2.22e+111    1.0

# %% [markdown]
# ## code_http_math vs writing test

# %%
result = pg.ttest(writing_read_score,
                  code_math_read_score,
                  correction=True)
 
# Print the result
result
# Out:
#                 T         dof alternative          p-val         CI95%  \
# T-test  30.345265  2564.36964   two-sided  4.343289e-173  [2.19, 2.49]
#
#          cohen-d        BF10  power
# T-test  1.154137  1.365e+171    1.0

# %% [markdown]
# ## The rest vs writing

# %%
result = pg.ttest(the_rest_read_score,
                  writing_read_score,
                  correction=True)
 
# Print the result
result
# Out:
#                T          dof alternative     p-val         CI95%   cohen-d  \
# T-test  3.423917  1481.370458   two-sided  0.000634  [0.07, 0.25]  0.093456
#
#           BF10    power
# T-test  10.237  0.94479

# %% [markdown]
# ## The rest vs code_http

# %%
result = pg.ttest(the_rest_read_score,
                  code_read_score,
                  correction=True)
 
# Print the result
result
# Out:
#                 T         dof alternative         p-val         CI95%  \
# T-test  29.179741  353.350421   two-sided  3.849253e-96  [2.53, 2.89]
#
#          cohen-d        BF10  power
# T-test  1.585935  2.912e+182    1.0

# %% [markdown]
# # Sample the rest t-test

# %% [markdown]
# ## Code math vs. writing

# %%
result_c_w = pg.ttest(writing_read_score,
                  code_math_read_score,
                  correction=True)
 
# Print the result
result_c_w
# Out:
#                 T         dof alternative          p-val         CI95%  \
# T-test  30.345265  2564.36964   two-sided  4.343289e-173  [2.19, 2.49]
#
#          cohen-d        BF10  power
# T-test  1.154137  1.365e+171    1.0

# %% [markdown]
# ## Code_math vs the rest

# %%
result_c_r = pg.ttest(the_rest_read_score_samples,
                  code_math_read_score,
                  correction=True)
 
# Print the result
result_c_r
# Out:
#                 T          dof alternative          p-val         CI95%  \
# T-test  32.430347  2541.637574   two-sided  2.239778e-193  [2.35, 2.66]
#
#          cohen-d        BF10  power
# T-test  1.240114  3.542e+191    1.0

# %% [markdown]
# ## the rest vs writing

# %%
result_w_r = pg.ttest(the_rest_read_score_samples,
                  writing_read_score,
                  correction=True)
 
# Print the result
result_w_r
# Out:
#                T          dof alternative    p-val         CI95%   cohen-d  \
# T-test  2.474778  2856.512519   two-sided  0.01339  [0.03, 0.29]  0.092535
#
#          BF10     power
# T-test  0.883  0.696025

# %%
sns.distplot(the_rest_read_score_samples, hist=False, label= 'The rest')
sns.distplot(writing_read_score, hist=False, label= 'Write')
sns.distplot(code_math_read_score, hist=False, label= 'Code & Math')
plt.title('Readability distribution for Writing, Coding, and The Rest group')
plt.legend()
# Out:
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/swimmingcircle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
result_w_r['T'][0]
# Out:
# 2.474778219790457

# %%
code_rest = pg.compute_effsize(the_rest_read_score_samples, code_math_read_score, paired=False, eftype='cohen')
code_write = pg.compute_effsize(writing_read_score, code_math_read_score, paired=False, eftype='cohen')
write_rest = pg.compute_effsize(writing_read_score, the_rest_read_score_samples, paired=False, eftype='cohen')
n_code = len(code_math_read_score)
s_code = np.var(code_math_read_score)
n_write = len(writing_read_score)
s_write = np.var(writing_read_score)
n_rest = len(the_rest_read_score_samples)
s_rest = np.var(the_rest_read_score_samples)
# s = sqrt(((n1 - 1) * s1 + (n2 - 1) * s2) / (n1 + n2 - 2))
s_code_rest = np.sqrt(((n_code - 1) * s_code + (n_rest - 1) * s_rest) / (n_code + n_rest - 2))
s_code_write = np.sqrt(((n_code - 1) * s_code + (n_write - 1) * s_write) / (n_code + n_write - 2))
s_rest_write = np.sqrt(((n_rest - 1) * s_rest + (n_write - 1) * s_write) / (n_rest + n_write - 2))

plot_data = [['code vs the rest', code_rest, s_code_rest, result_c_r['p-val'][0], result_c_r['T'][0]], ['code vs write', code_write, s_code_write, result_c_w['p-val'][0], result_c_w['T'][0]], ['write vs the rest', write_rest, s_rest_write, result_w_r['p-val'][0],result_w_r['T'][0]]]
  

# Create the pandas DataFrame
plot_df = pd.DataFrame(plot_data, columns=['Comparison', 'Effect_size', 'Error', 'P value', 'T'])
plot_df
# Out:
#           Comparison  Effect_size     Error        P value          T
# 0   code vs the rest     1.240114  2.020112  2.239778e-193  32.430347
# 1      code vs write     1.154137  2.029717  4.343289e-173  30.345265
# 2  write vs the rest    -0.092535  1.757340   1.338954e-02   2.474778

# %%
fig, ax = plt.subplots()
ax.bar(plot_df['Comparison'], plot_df['Effect_size'],
       yerr=plot_df['Error'],
       align='center',
       alpha=0.5,
       ecolor='black',
       capsize=10)
ax.set_xticks(plot_df['Comparison'])
# ax.set_xticklabels(labels)
# ax.set_title('Coefficent of Thermal Expansion (CTE) of Three Metals')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()

# %%
sns.barplot(x = plot_df['Comparison'], y = plot_df['Effect_size'], yerr = plot_df['Error'],
       ecolor='black',
       capsize=10, errwidth = 2,)
plt.gca().yaxis.grid(True)
plt.title('Effect size of group comparison')
plt.tight_layout()
